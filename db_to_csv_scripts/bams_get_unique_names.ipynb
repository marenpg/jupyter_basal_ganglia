# %%
import os
import pandas as pd

root_dir = "../Data/csvs/bams2_connectivity/"

def getAllUniqueNames():
    names = set()
    
    for filename in os.listdir(root_dir):
        if filename.endswith(".csv"):
            df_bams_conn = pd.read_csv(root_dir + filename, dtype="object")
            unique_from = df_bams_conn.From.unique()
            unique_to = df_bams_conn.To.unique()
            for name in unique_from:
                names.add(name)
            for name2 in unique_to:
                names.add(name2)

    return sorted(names)

def getBasalGangliaAreas():
    names = set()
    for filename in os.listdir(root_dir):
        if filename.endswith("outputs.csv"):
            df_bams_conn = pd.read_csv(root_dir + filename, dtype="object")
            unique_from = df_bams_conn.From.unique()
            for name in unique_from:
                names.add(name)
    return sorted(names)

sorted_all = getAllUniqueNames()
print("All sorted")
for elem in sorted_all:
    print(elem)
    
sorted_bg = getBasalGangliaAreas()
print("Basal ganglia")
for elem in sorted_bg:
    print(elem)
# Out:
# All sorted
# Accessory olfactory bulb (AOB)
# Agranular insular area dorsal part (AId)
# Agranular insular area posterior part (AIp)
# Agranular insular area ventral part (AIv)
# Anterior amygdaloid area (AAA)
# Anterior cingulate area (ACA)
# Anterior cingulate area dorsal part (ACAd)
# Anterior cingulate area ventral part (ACAv)
# Anterior hypothalamic area (AHA)
# Anterior hypothalamic central part (AHNc)
# Anterior hypothalamic nucleus anterior part (AHNa)
# Anterior hypothalamic posterior part (AHNp)
# Anterior olfactory nucleus (AON)
# Anterior olfactory nucleus posteroventral part (AONpv)
# Anterior periventricular nucleus of the hypothalamus (PVa)
# Anteroventral periventricular nucleus (AVPV)
# Barrington nucleus (B)
# Basolateral nucleus of the amygdala (BLA)
# Basolateral nucleus of the amygdala anterior part (BLAa)
# Basolateral nucleus of the amygdala posterior part (BLAp)
# Basomedial nucleus of the amygdala anterior part (BMAa)
# Basomedial nucleus of the amygdala posterior part (BMAp)
# Bed nuclei of the stria terminalis anterior division anterodorsal area (BSTad)
# Bed nuclei of the stria terminalis anterior division anteroventral area (BSTav)
# Bed nuclei of the stria terminalis anterior division dorsolateral nucleus (BSTdl)
# Bed nuclei of the stria terminalis anterior division dorsomedial nucleus (BSTdm)
# Bed nuclei of the stria terminalis anterior division fusiform nucleus (BSTfu)
# Bed nuclei of the stria terminalis anterior division magnocellular nucleus (BSTmg)
# Bed nuclei of the stria terminalis anterior division ventral nucleus (BSTv)
# Bed nuclei of the stria terminalis anterolateral area (BSTal)
# Bed nuclei of the stria terminalis anteromedial area (BSTam)
# Bed nuclei of the stria terminalis dorsal nucleus (BSTd)
# Bed nuclei of the stria terminalis oval nucleus (BSTov)
# Bed nuclei of the stria terminalis posterior division interfascicular nucleus (BSTif)
# Bed nuclei of the stria terminalis posterior division principal nucleus (BSTpr)
# Bed nuclei of the stria terminalis posterior division transverse nucleus (BSTtr)
# Bed nuclei of the stria terminalis rhomboid nucleus (BSTrh)
# Bed nuclei of the stria terminalis, anterior division, subcommisural zone (BSTsc)
# Bed nucleus of the accessory olfactory part (BA)
# Bed nucleus of the anterior commissure (BAC)
# Bed nucleus of the stria medularis (BSM)
# Caudoputamen (CP)
# Central linear nucleus raphe (CLI)
# Central nucleus of amygdala (CEA)
# Central nucleus of amygdala capsular part (CEAc)
# Central nucleus of amygdala lateral part (CEAl)
# Central nucleus of amygdala medial part (CEAm)
# Cortical nucleus of the amygdala anterior part (COAa)
# Cortical nucleus of the amygdala posterior part lateral zone (COApl)
# Cortical nucleus of the amygdala posterior part medial zone (COApm)
# Dorsal auditory areas (AUDd)
# Dorsal nucleus raphe (DR)
# Dorsal premammillary nucleus (PMd)
# Dorsomedial nucleus of the hypothalamus anterior part (DMHa)
# Ectorhinal area (ECT)
# Endopiriform nucleus dorsal part (EPd)
# Entorhinal area (ENT)
# Entorhinal area medial part, ventral zone (ENTMv)
# Entorhinal area, lateral part (ENTl)
# Field CA1 (CA1)
# Field CA2 (CA2)
# Field CA3 (CA3)
# Fundus of the striatum (FS)
# Globus pallidus (GP)
# Globus pallidus external segment (GPe)
# Globus pallidus internal segment (GPi)
# Globus pallidus lateral segment (GPl)
# Globus pallidus medial segment (GPm)
# Gustatory areas (GU)
# Induseum griseum (IG)
# Infralimbic area (ILA)
# Intercalated nuclei of the amygdala (IA)
# Interfascicular nucleus raphe (IF)
# Intermediate periventricular nucleus of the hypothalamus (PVI)
# Islands of Calleja (isl)
# Lateral habenula (LH)
# Lateral hypothalamic area (LHA)
# Lateral hypothalamic area juxtaparaventricular region (LHAjp)
# Lateral hypothalamic area subfornical region anterior zone (LHAsfa)
# Lateral hypothalamic area suprafornical region (LHAs)
# Lateral nucleus of the amygdala (LA)
# Lateral preoptic area (LPO)
# Lateral septal nucleus ventral part (LSv)
# Magnocellular preoptic nucleus (MA)
# Main olfactory bulb (MOB)
# Major island of Calleja (islm)
# Medial mammillary nucleus (MM)
# Medial nucleus of the amygdala anterodorsal part (MEAad)
# Medial nucleus of the amygdala anteroventral part (MEAav)
# Medial nucleus of the amygdala posterodorsal part (MEApd)
# Medial nucleus of the amygdala posterodorsal part,sublayer a (MEApd-a)
# Medial nucleus of the amygdala posterodorsal part,sublayer c (MEApd-c)
# Medial nucleus of the amygdala posteroventral part (MEApv)
# Medial preoptic area (MPO)
# Medial preoptic nucleus central part (MPNc)
# Medial preoptic nucleus lateral part (MPNl)
# Medial preoptic nucleus medial part (MPNm)
# Medial septal nucleus (MS)
# Mediodorsal nucleus of the thalamus (MD)
# Nucleus accumbens (ACB)
# Nucleus incertus compact part (NIc)
# Nucleus incertus diffuse part (NId)
# Nucleus of the diagonal band (NDB)
# Nucleus of the lateral olfactory tract (NLOT)
# Olfactory tubercle (OT)
# Olfactory tubercle molecular layer (OT1)
# Olfactory tubercle polymorph layer (OT3)
# Olfactory tubercle pyramidal layer (OT2)
# Orbital area medial part (ORBm)
# Orbital area ventral part (ORBv)
# Parabrachial nucleus lateral division central lateral part (PBlc)
# Parabrachial nucleus lateral division external lateral part (PBle)
# Parabrachial nucleus lateral division ventral lateral part (PBlv)
# Parasubiculum (PAR)
# Pedunculopontine nucleus (PPN)
# Periaqueductal gray (PAG)
# Perirhinal area (PERI)
# Piriform area (PIR)
# Posterior hypothalamic nucleus (PH)
# Posterior nucleus of the amygdala (PA)
# Posterior parietal association areas (PTLp)
# Posterior periventricular nucleus of the hypothalamus (PVp)
# Postpiriform transition area (TR)
# Postsubiculum (POST)
# Precommissural nucleus (PRC)
# Prelimbic area (PL)
# Presubiculum (PRE)
# Primary motor area (MOp)
# Retina (R)
# Retrorubral area (RR)
# Retrosplenial area (RSP)
# Retrosplenial area lateral agranular part (RSPagl)
# Rostral linear nucleus raphe (RL)
# Secondary motor area (MOs)
# Septofimbrial nucleus (SF)
# Septohippocampal nucleus (SH)
# Subiculum ventral part (SUBv)
# Substantia innominata (SI)
# Substantia nigra (SN)
# Substantia nigra reticular part (SNr)
# Supramammillary nucleus (SUM)
# Supraoptic nucleus (SO)
# Taenia tecta ventral part (TTv)
# Triangular nucleus of the septum (TRS)
# Tuberomammillary nucleus (TM)
# Ventral auditory areas (AUDv)
# Ventral premammillary nucleus (PMv)
# Ventral tegmental area (VTA)
# Ventromedial nucleus of the hypothalamus central part (VMHc)
# Ventromedial nucleus of the hypothalamus dorsomedial part (VMHdm)
# Ventromedial nucleus of the hypothalamus ventrolateral part (VMHvl)
# Visceral area (VISC)
# Basal ganglia
# Anterior amygdaloid area (AAA)
# Bed nuclei of the stria terminalis anterior division dorsomedial nucleus (BSTdm)
# Bed nucleus of the accessory olfactory part (BA)
# Bed nucleus of the anterior commissure (BAC)
# Bed nucleus of the stria medularis (BSM)
# Caudoputamen (CP)
# Central nucleus of amygdala capsular part (CEAc)
# Central nucleus of amygdala lateral part (CEAl)
# Central nucleus of amygdala medial part (CEAm)
# Fundus of the striatum (FS)
# Globus pallidus (GP)
# Globus pallidus external segment (GPe)
# Globus pallidus internal segment (GPi)
# Globus pallidus lateral segment (GPl)
# Globus pallidus medial segment (GPm)
# Intercalated nuclei of the amygdala (IA)
# Islands of Calleja (isl)
# Magnocellular preoptic nucleus (MA)
# Major island of Calleja (islm)
# Medial nucleus of the amygdala anterodorsal part (MEAad)
# Medial nucleus of the amygdala anteroventral part (MEAav)
# Medial nucleus of the amygdala posterodorsal part (MEApd)
# Medial nucleus of the amygdala posteroventral part (MEApv)
# Medial septal nucleus (MS)
# Nucleus accumbens (ACB)
# Nucleus of the diagonal band (NDB)
# Olfactory tubercle (OT)
# Olfactory tubercle molecular layer (OT1)
# Olfactory tubercle polymorph layer (OT3)
# Olfactory tubercle pyramidal layer (OT2)
# Substantia innominata (SI)
# Triangular nucleus of the septum (TRS)
